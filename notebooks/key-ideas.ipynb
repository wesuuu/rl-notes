# %% [markdown]
# ## RL process
#
# RL optimizes a control task
#
# ![basic-2.jpg](attachment:basic-2.jpg)
#
# ## Basic optimization workflow
#
# Key objects:
#
# - Agents
# - Environment
# - Space
# - Time
# - Actions
#
# ![basic.jpg](attachment:basic.jpg)
#
# ## Using gym
#
# 5 steps to training
#
# ```python
# import gym
# env = gym.make('CarRacing-v0')
# env.reset()
# env.step(action)
# env.render()
# ```
#
# ## Why deep RL?
#
# Storing all potential actions and outcomes becomes intractable for many games
#
# Need a different loss function to learn other than simply maximizing the outcome
